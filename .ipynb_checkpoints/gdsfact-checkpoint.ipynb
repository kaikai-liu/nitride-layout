# %%
import gdsfactory as gf
from gdsfactory.generic_tech import get_generic_pdk
gf.config.rich_output()
PDK = get_generic_pdk()
PDK.activate()

# %%
# Honeywell CMOS mask size 21.6 mm by 26 mm
# UCSB in-house mask size 21 mm by 25 mm
maskLH = 21.6e3
maskLV = 26e3
# maskLH = 21e3
# maskHV = 25e3

wg_ring = 11
wg_bus = 7
gap = 5.2
R = 8840

# %%
# Create a blank component (essentially an empty GDS cell with some special features)
c = gf.Component("myComponent")

# Create and add a polygon from separate lists of x points and y points
# (Can also be added like [(x1,y1), (x2,y2), (x3,y3), ... ]
poly1 = c.add_polygon(
    [(-8, 6, 7, 9), (-6, 8, 17, 5)], layer=1
)  # GDS layers are tuples of ints (but if we use only one number it assumes the other number is 0)

# %%
c = gf.Component("enclosure1")
r = c << gf.components.ring_single()

# %%
c.write_gds("demo.gds", with_metadata=True)
# Out:
# 2023-06-24 17:31:30.468 | INFO     | gdsfactory.component:_write_library:1946 - Wrote to 'demo.gds'
# 2023-06-24 17:31:30.484 | INFO     | gdsfactory.component:_write_library:1950 - Write YAML metadata to 'demo.yml'
# WindowsPath('demo.gds')

# %%
# Create some new geometry from the functions available in the geometry library
t = gf.components.text("Hello!")
r = gf.components.rectangle(size=[5, 10], layer=(2, 0))

# Add references to the new geometry to c, our blank component
text1 = c.add_ref(t)  # Add the text we created as a reference
# Using the << operator (identical to add_ref()), add the same geometry a second time
text2 = c << t
r = c << r  # Add the rectangle we created

# Now that the geometry has been added to "c", we can move everything around:
text1.move([25, 0])
text2.move([5, 30])
# Out:
# ComponentReference (parent Component "text_textHello", ports [], origin (5.0, 30.0), rotation 0.0, x_reflection False)

# %%
c = gf.Component("enclosure1")
r = c << gf.components.ring_single()

# %%
c.plot_matplotlib()

# %%
# Create a blank Component
p = gf.Component("component_with_polygon")

# Add a polygon
xpts = [0, 0, 5, 6, 9, 12]
ypts = [0, 1, 1, 2, 2, 0]
p.add_polygon([xpts, ypts])
p.plot_matplotlib()

# %%
c = gf.Component("Components")
poly1 = c.add_ref(p)
poly2 = c.add_ref(p)
poly1.movey(2)
c.plot_matplotlib()

# %%
# Add a 2nd polygon to "p"
xpts = [14, 14, 16, 16]
ypts = [0, 2, 2, 0]
p.add_polygon([xpts, ypts], layer=(1, 0))
p
# Out:
# 2023-06-24 17:34:21.303 | INFO     | gdsfactory.klive:show:55 - Message from klive: {"version": "0.2.2", "type": "open", "file": "C:\\Users\\lkk12\\AppData\\Local\\Temp\\gdsfactory\\component_with_polygon.gds"}
# 2023-06-24 17:34:21.554 | INFO     | kfactory.conf:__init__:105 - LogLevel: INFO
# AppLayout(children=(Output(layout=Layout(grid_area='footer')), VBox(children=(Button(description='clear annota…
# component_with_polygon: uid f767c87f, ports [], references [], 2 polygons

# %%
c2 = gf.Component("More")
c2_1 = c2 << c
c2_2 = c2 << c
c2_2.movex(15)
c2_3 = c2 << c
c2_3.movex(30)
c2.plot_matplotlib()
